# %%
import pandas as pd

# %%
df = pd.read_csv("/Users/gorazdfilipovski/PycharmProjects/VNP/data/aud_data/aud_4_and_5/user_behavior_dataset.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   User ID                     700 non-null    int64
#  1   Device Model                700 non-null    object
#  2   Operating System            700 non-null    object
#  3   App Usage Time (min/day)    700 non-null    int64
#  4   Screen On Time (hours/day)  700 non-null    float64
#  5   Battery Drain (mAh/day)     700 non-null    int64
#  6   Number of Apps Installed    700 non-null    int64
#  7   Data Usage (MB/day)         700 non-null    int64
#  8   Age                         700 non-null    int64
#  9   Gender                      700 non-null    object
#  10  User Behavior Class         700 non-null    int64
# dtypes: float64(1), int64(7), object(3)
# memory usage: 60.3+ KB

# %%
df.sample(5)
# Out:
#      User ID        Device Model Operating System  App Usage Time (min/day)  \
# 535      536  Samsung Galaxy S21          Android                       139
# 547      548           iPhone 12              iOS                       139
# 249      250      Google Pixel 5          Android                        75
# 475      476  Samsung Galaxy S21          Android                       412
# 274      275           iPhone 12              iOS                       122
#
#      Screen On Time (hours/day)  Battery Drain (mAh/day)  \
# 535                         3.3                      937
# 547                         2.6                      658
# 249                         1.9                      537
# 475                         6.2                     2201
# 274                         2.6                      639
#
#      Number of Apps Installed  Data Usage (MB/day)  Age  Gender  \
# 535                        24                  573   25  Female
# ...

# %%
import seaborn as sns

# %%
sns.pairplot(df)

# %%
df.hist()
# Out:
# array([[<Axes: title={'center': 'User ID'}>,
#         <Axes: title={'center': 'App Usage Time (min/day)'}>,
#         <Axes: title={'center': 'Screen On Time (hours/day)'}>],
#        [<Axes: title={'center': 'Battery Drain (mAh/day)'}>,
#         <Axes: title={'center': 'Number of Apps Installed'}>,
#         <Axes: title={'center': 'Data Usage (MB/day)'}>],
#        [<Axes: title={'center': 'Age'}>,
#         <Axes: title={'center': 'User Behavior Class'}>, <Axes: >]],
#       dtype=object)

# %%
df['User ID'].hist()
# Out:
# <Axes: >

# %%
df.sample(5)
# Out:
#      User ID    Device Model Operating System  App Usage Time (min/day)  \
# 576      577  Google Pixel 5          Android                       554
# 255      256       OnePlus 9          Android                       397
# 105      106    Xiaomi Mi 11          Android                        66
# 668      669       iPhone 12              iOS                       170
# 374      375       OnePlus 9          Android                        69
#
#      Screen On Time (hours/day)  Battery Drain (mAh/day)  \
# 576                        10.3                     2776
# 255                         7.0                     2352
# 105                         1.2                      585
# 668                         2.4                     1039
# 374                         1.3                      434
#
#      Number of Apps Installed  Data Usage (MB/day)  Age  Gender  \
# 576                        83                 1606   34  Female
# ...

# %%
df.isna().sum()
# Out:
# User ID                       0
# Device Model                  0
# Operating System              0
# App Usage Time (min/day)      0
# Screen On Time (hours/day)    0
# Battery Drain (mAh/day)       0
# Number of Apps Installed      0
# Data Usage (MB/day)           0
# Age                           0
# Gender                        0
# User Behavior Class           0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()

df.Gender = encoder.fit_transform(df.Gender)

# %%
df.sample(5)
# Out:
#      User ID        Device Model Operating System  App Usage Time (min/day)  \
# 249      250      Google Pixel 5          Android                        75
# 31        32        Xiaomi Mi 11          Android                       197
# 80        81           OnePlus 9          Android                       565
# 125      126  Samsung Galaxy S21          Android                       535
# 453      454      Google Pixel 5          Android                        88
#
#      Screen On Time (hours/day)  Battery Drain (mAh/day)  \
# 249                         1.9                      537
# 31                          4.6                     1660
# 80                         10.6                     2475
# 125                        11.8                     2858
# 453                         1.3                      557
#
#      Number of Apps Installed  Data Usage (MB/day)  Age  Gender  \
# 249                        13                  230   58       0
# ...

# %%
df['Device Model'] = encoder.fit_transform(df['Device Model'])
df['Operating System'] = encoder.fit_transform(df['Operating System'])

# %%
df.sample(5)
# Out:
#      User ID  Device Model  Operating System  App Usage Time (min/day)  \
# 584      585             1                 0                        73
# 131      132             3                 0                       320
# 432      433             0                 0                       534
# 514      515             2                 0                       466
# 356      357             4                 1                       291
#
#      Screen On Time (hours/day)  Battery Drain (mAh/day)  \
# 584                         1.3                      538
# 131                         7.2                     2056
# 432                        10.4                     2672
# 514                         7.1                     1984
# 356                         4.1                     1326
#
#      Number of Apps Installed  Data Usage (MB/day)  Age  Gender  \
# 584                        19                  175   30       0
# ...

# %%
df.drop(["User ID"],axis=1,inplace=True)

# %%
df.sample(5)
# Out:
#      Device Model  Operating System  App Usage Time (min/day)  \
# 119             0                 0                        97
# 564             3                 0                       290
# 581             2                 0                       148
# 643             1                 0                       105
# 430             4                 1                       266
#
#      Screen On Time (hours/day)  Battery Drain (mAh/day)  \
# 119                         2.7                     1018
# 564                         4.4                     1272
# 581                         2.7                      625
# 643                         3.3                      723
# 430                         5.5                     1238
#
#      Number of Apps Installed  Data Usage (MB/day)  Age  Gender  \
# 119                        37                  428   41       1
# 564                        55                  910   44       1
# ...

# %%
from sklearn.naive_bayes import GaussianNB

model = GaussianNB()

# %%
from sklearn.model_selection import train_test_split

target = 'User Behavior Class'
X = df.drop([target],axis=1)
Y= df[target]
X_train, X_test, y_train, y_test = train_test_split(X,Y,test_size=0.2,shuffle=True)

# %%
model.fit(X_train,y_train)
# Out:
# GaussianNB()

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score,f1_score,confusion_matrix,classification_report

print(accuracy_score(y_test,y_pred))
print(f1_score(y_test,y_pred,average='micro'))
print(f1_score(y_test,y_pred,average='macro'))
print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# 1.0
# 1.0
# 1.0
# [[28  0  0  0  0]
#  [ 0 25  0  0  0]
#  [ 0  0 41  0  0]
#  [ 0  0  0 26  0]
#  [ 0  0  0  0 20]]
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        28
#            2       1.00      1.00      1.00        25
#            3       1.00      1.00      1.00        41
#            4       1.00      1.00      1.00        26
#            5       1.00      1.00      1.00        20
#
#     accuracy                           1.00       140
#    macro avg       1.00      1.00      1.00       140
# weighted avg       1.00      1.00      1.00       140
